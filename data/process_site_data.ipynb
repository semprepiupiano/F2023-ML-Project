# %%
import pandas as pd
import pickle
import matplotlib

# %%
with open("site_data.pkl", "rb") as f:
    site_data = pickle.load(f)
site_data
# Out:
# [{'state_code': '51',
#   'county_code': '003',
#   'site_number': '0001',
#   'parameter_code': '44201',
#   'poc': 1,
#   'latitude': 38.07657,
#   'longitude': -78.50397,
#   'datum': 'WGS84',
#   'parameter': 'Ozone',
#   'sample_duration_code': '1',
#   'sample_duration': '1 HOUR',
#   'pollutant_standard': 'Ozone 1-hour 1979',
#   'date_local': '2017-03-01',
#   'units_of_measure': 'Parts per million',
#   'event_type': 'No Events',
#   'observation_count': 24,
#   'observation_percent': 100.0,
#   'validity_indicator': 'Y',
#   'arithmetic_mean': 0.031125,
#   'first_max_value': 0.038,
#   'first_max_hour': 13,
#   'aqi': None,
#   'method_code': '047',
#   'method': 'INSTRUMENTAL - ULTRA VIOLET',
#   'local_site_name': 'Albemarle High School',
#   'site_address': 'Lambs Lane, behind Albemarle High School Athletic Field',
#   'state': 'Virginia',
#   'county': 'Albemarle',
#   'city': 'Not in a city',
#   'cbsa_code': '16820',
#   'cbsa': 'Charlottesville, VA',
# ...

# %%
unique_parameter_names = set([x['parameter'] for x in site_data])
unique_parameter_names
# Out:
# {'Ozone'}

# %%
dates = list(set([x['date_local'] for x in site_data]))
dates.sort()

# %%
dates
# Out:
# ['2017-02-28',
#  '2017-03-01',
#  '2017-03-02',
#  '2017-03-03',
#  '2017-03-04',
#  '2017-03-05',
#  '2017-03-06',
#  '2017-03-07',
#  '2017-03-08',
#  '2017-03-09',
#  '2017-03-10',
#  '2017-03-11',
#  '2017-03-13',
#  '2017-03-14',
#  '2017-03-15',
#  '2017-03-16',
#  '2017-03-17',
#  '2017-03-18',
#  '2017-03-19',
#  '2017-03-20',
#  '2017-03-21',
#  '2017-03-22',
#  '2017-03-23',
#  '2017-03-24',
#  '2017-03-25',
#  '2017-03-26',
#  '2017-03-27',
#  '2017-03-28',
#  '2017-03-29',
#  '2017-03-30',
#  '2017-03-31',
#  '2017-04-01',
#  '2017-04-02',
#  '2017-04-03',
#  '2017-04-04',
#  '2017-04-05',
#  '2017-04-06',
#  '2017-04-07',
#  '2017-04-08',
#  '2017-04-09',
#  '2017-04-10',
#  '2017-04-11',
#  '2017-04-12',
#  '2017-04-13',
#  '2017-04-14',
#  '2017-04-15',
#  '2017-04-16',
#  '2017-04-17',
#  '2017-04-18',
#  '2017-04-19',
#  '2017-04-20',
#  '2017-04-21',
#  '2017-04-22',
#  '2017-04-23',
#  '2017-04-24',
#  '2017-04-25',
#  '2017-04-26',
#  '2017-04-27',
# ...
